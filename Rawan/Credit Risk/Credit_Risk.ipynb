# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("credit_risk_dataset.csv")

# %%
df.head(10)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
# 6          26          77100                  RENT                8.0
# 7          24          78956                  RENT                5.0
# 8          24          83000                  RENT                8.0
# 9          21          10000                   OWN                6.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
# 5     VENTURE          A       2500           7.14            1
# 6   EDUCATION          B      35000          12.42            1
# 7     MEDICAL          B      35000          11.11            1
# 8    PERSONAL          A      35000           8.90            1
# 9     VENTURE          D       1600          14.74            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4
# 5                 0.25                         N                           2
# 6                 0.45                         N                           3
# 7                 0.44                         N                           4
# 8                 0.42                         N                           2
# 9                 0.16                         N                           3

# %%
df.shape
# Out:
# (32581, 12)

# %%
df.rename(columns = {'loan_int_rate':'loan_interest_rate','cb_person_default_on_file':'historical_default','cb_person_cred_hist_length':'credit_history_length'}, inplace = True)

# %%
df.head(10)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
# 6          26          77100                  RENT                8.0
# 7          24          78956                  RENT                5.0
# 8          24          83000                  RENT                8.0
# 9          21          10000                   OWN                6.0
#
#   loan_intent loan_grade  loan_amnt  loan_interest_rate  loan_status  \
# 0    PERSONAL          D      35000               16.02            1
# 1   EDUCATION          B       1000               11.14            0
# 2     MEDICAL          C       5500               12.87            1
# 3     MEDICAL          C      35000               15.23            1
# 4     MEDICAL          C      35000               14.27            1
# 5     VENTURE          A       2500                7.14            1
# 6   EDUCATION          B      35000               12.42            1
# 7     MEDICAL          B      35000               11.11            1
# 8    PERSONAL          A      35000                8.90            1
# 9     VENTURE          D       1600               14.74            1
#
#    loan_percent_income historical_default  credit_history_length
# 0                 0.59                  Y                      3
# 1                 0.10                  N                      2
# 2                 0.57                  N                      3
# 3                 0.53                  N                      2
# 4                 0.55                  Y                      4
# 5                 0.25                  N                      2
# 6                 0.45                  N                      3
# 7                 0.44                  N                      4
# 8                 0.42                  N                      2
# 9                 0.16                  N                      3

# %% [markdown]
# ### Check Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   person_age             32581 non-null  int64
#  1   person_income          32581 non-null  int64
#  2   person_home_ownership  32581 non-null  object
#  3   person_emp_length      31686 non-null  float64
#  4   loan_intent            32581 non-null  object
#  5   loan_grade             32581 non-null  object
#  6   loan_amnt              32581 non-null  int64
#  7   loan_interest_rate     29465 non-null  float64
#  8   loan_status            32581 non-null  int64
#  9   loan_percent_income    32581 non-null  float64
#  10  historical_default     32581 non-null  object
#  11  credit_history_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
df.nunique()
# Out:
# person_age                 58
# person_income            4295
# person_home_ownership       4
# person_emp_length          36
# loan_intent                 6
# loan_grade                  7
# loan_amnt                 753
# loan_interest_rate        348
# loan_status                 2
# loan_percent_income        77
# historical_default          2
# credit_history_length      29
# dtype: int64

# %%
for col in ['person_home_ownership', 'loan_intent', 'loan_grade', 'loan_status', 'historical_default']:
    print('\n',df[col].value_counts())
# Out:
#  person_home_ownership
# RENT        16446
# MORTGAGE    13444
# OWN          2584
# OTHER         107
# Name: count, dtype: int64
#
#  loan_intent
# EDUCATION            6453
# MEDICAL              6071
# VENTURE              5719
# PERSONAL             5521
# DEBTCONSOLIDATION    5212
# HOMEIMPROVEMENT      3605
# Name: count, dtype: int64
#
#  loan_grade
# A    10777
# B    10451
# C     6458
# D     3626
# E      964
# F      241
# G       64
# Name: count, dtype: int64
#
#  loan_status
# 0    25473
# 1     7108
# Name: count, dtype: int64
#
#  historical_default
# N    26836
# Y     5745
# Name: count, dtype: int64

# %% [markdown]
# ### Check Null Values

# %%
df.isnull().mean()/100
# Out:
# person_age               0.000000
# person_income            0.000000
# person_home_ownership    0.000000
# person_emp_length        0.000275
# loan_intent              0.000000
# loan_grade               0.000000
# loan_amnt                0.000000
# loan_interest_rate       0.000956
# loan_status              0.000000
# loan_percent_income      0.000000
# historical_default       0.000000
# credit_history_length    0.000000
# dtype: float64

# %%
df['person_emp_length'] = df['person_emp_length'].fillna(df['person_emp_length'].median())

# %%
df.isnull().mean()/100
# Out:
# person_age               0.000000
# person_income            0.000000
# person_home_ownership    0.000000
# person_emp_length        0.000000
# loan_intent              0.000000
# loan_grade               0.000000
# loan_amnt                0.000000
# loan_interest_rate       0.000956
# loan_status              0.000000
# loan_percent_income      0.000000
# historical_default       0.000000
# credit_history_length    0.000000
# dtype: float64

# %%
df.dropna(subset=['loan_interest_rate'], inplace=True)

# %%
df.isnull().mean()/100
# Out:
# person_age               0.0
# person_income            0.0
# person_home_ownership    0.0
# person_emp_length        0.0
# loan_intent              0.0
# loan_grade               0.0
# loan_amnt                0.0
# loan_interest_rate       0.0
# loan_status              0.0
# loan_percent_income      0.0
# historical_default       0.0
# credit_history_length    0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 144

# %%
df[df.duplicated()]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15975          23          42000                  RENT                5.0
# 15989          23          90000              MORTGAGE                7.0
# 15995          24          48000              MORTGAGE                4.0
# 16025          24          10000                  RENT                8.0
# 16028          23         100000              MORTGAGE                7.0
# ...           ...            ...                   ...                ...
# 31947          40          38000                  RENT                4.0
# 32010          42          39996              MORTGAGE                2.0
# 32047          36         250000                  RENT                2.0
# 32172          49         120000              MORTGAGE               12.0
# 32259          39          40000                   OWN                4.0
#
#              loan_intent loan_grade  loan_amnt  loan_interest_rate  \
# 15975            VENTURE          B       6000                9.99
# 15989          EDUCATION          B       8000               10.36
# 15995            MEDICAL          A       4000                5.42
# 16025           PERSONAL          A       3000                7.90
# 16028          EDUCATION          A      15000                7.88
# ...                  ...        ...        ...                 ...
# 31947  DEBTCONSOLIDATION          D       7000               15.99
# 32010    HOMEIMPROVEMENT          A       2500                5.42
# 32047  DEBTCONSOLIDATION          A      20000                7.88
# 32172            MEDICAL          B      12000               10.99
# 32259            VENTURE          B       1000               10.37
#
#        loan_status  loan_percent_income historical_default  \
# 15975            0                 0.14                  N
# 15989            0                 0.09                  N
# 15995            0                 0.08                  N
# 16025            1                 0.30                  N
# 16028            0                 0.15                  N
# ...            ...                  ...                ...
# 31947            1                 0.18                  N
# 32010            0                 0.06                  N
# 32047            0                 0.08                  N
# 32172            0                 0.10                  N
# 32259            0                 0.03                  N
#
#        credit_history_length
# 15975                      4
# 15989                      3
# 15995                      4
# 16025                      3
# 16028                      4
# ...                      ...
# 31947                     16
# 32010                     12
# 32047                     17
# 32172                     12
# 32259                     16
#
# [144 rows x 12 columns]

# %%
# df.drop_duplicates(inplace=True)

# %% [markdown]
# # Understand the Data & Deal with Outliers

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  29465.000000   2.946500e+04       29465.000000  29465.000000
# mean      27.714712   6.602047e+04           4.766537   9584.744612
# std        6.300193   6.190142e+04           4.097976   6316.272282
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.910000e+04           7.000000  12250.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_interest_rate   loan_status  loan_percent_income  \
# count        29465.000000  29465.000000         29465.000000
# mean            11.011695      0.219379             0.170110
# std              3.240459      0.413833             0.106879
# min              5.420000      0.000000             0.000000
# 25%              7.900000      0.000000             0.090000
# 50%             10.990000      0.000000             0.150000
# 75%             13.470000      0.000000             0.230000
# max             23.220000      1.000000             0.830000
#
#        credit_history_length
# count           29465.000000
# mean                5.788257
# std                 4.031987
# min                 2.000000
# 25%                 3.000000
# 50%                 4.000000
# 75%                 8.000000
# max                30.000000

# %% [markdown]
# ### Person Age Outliers

# %%
df[df['person_age']>90].value_counts()
# Out:
# person_age  person_income  person_home_ownership  person_emp_length  loan_intent  loan_grade  loan_amnt  loan_interest_rate  loan_status  loan_percent_income  historical_default  credit_history_length
# 123         80004          RENT                   2.0                EDUCATION    B           20400      10.25               0            0.25                 N                   3                        1
# 144         200000         MORTGAGE               4.0                EDUCATION    B           6000       11.86               0            0.03                 N                   2                        1
#             250000         RENT                   4.0                VENTURE      C           4800       13.57               0            0.02                 N                   3                        1
#             6000000        MORTGAGE               12.0               PERSONAL     C           5000       12.73               0            0.00                 N                   25                       1
# Name: count, dtype: int64

# %%
df['person_age'].value_counts().head(10)
# Out:
# person_age
# 23    3518
# 22    3265
# 24    3214
# 25    2783
# 26    2256
# 27    1925
# 28    1672
# 29    1531
# 30    1174
# 21    1111
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize = (10, 5))
x = df['person_age'].value_counts().index
y = df['person_age'].value_counts().values
plt.bar(x, y)
plt.xlabel('Person Age')
plt.ylabel('Count')
plt.title('Distribution of Person Age')
plt.show()

# %%
df.drop(df[df['person_age'] > 90].index, axis=0,inplace = True)

# %% [markdown]
# ### Person Employee length Outliers

# %%
sns.boxplot(df['person_emp_length'])
plt.xlabel('Person Employee Length')
plt.ylabel('Count')
plt.title('Distribution of Person Employee Length')
plt.show()

# %%
df[df['person_emp_length'] > 41].value_counts()
# Out:
# person_age  person_income  person_home_ownership  person_emp_length  loan_intent  loan_grade  loan_amnt  loan_interest_rate  loan_status  loan_percent_income  historical_default  credit_history_length
# 21          192000         MORTGAGE               123.0              VENTURE      A           20000      6.54                0            0.10                 N                   4                        1
# 22          59000          RENT                   123.0              PERSONAL     D           35000      16.02               1            0.59                 Y                   3                        1
# Name: count, dtype: int64

# %%
# median = df['person_emp_length'].median()
df.loc[df['person_emp_length']>41,'person_emp_length'] = np.NaN

# %%
fig = plt.figure(figsize = (10, 5))
x = df['person_emp_length'].value_counts().index
y = df['person_emp_length'].value_counts().values
plt.bar(x, y)
plt.xlabel('person_emp_length')
plt.ylabel('Count')
plt.title('Distribution of person_emp_length')
plt.show()

# %%
sns.boxplot(df['person_emp_length'])
plt.xlabel('Person Employee Length')
plt.ylabel('Count')
plt.title('Distribution of Person Employee Length')
plt.show()

# %% [markdown]
# ### Person Income outliers

# %%
sns.boxplot(df['person_income'])
plt.xlabel('Person Income')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Calculate Q1, Q3, and IQR
Q1 = df['person_income'].quantile(0.25)
Q3 = df['person_income'].quantile(0.75)
IQR = Q3 - Q1

# Calculate lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['person_income'] < lower_bound) | (df['person_income'] > upper_bound)]

print("Outliers:\n",outliers[['person_age','person_income']])
# Out:
# Outliers:
#         person_age  person_income
# 15             23         500000
# 20             25         162500
# 33             25         306000
# 34             26         300000
# 42             26         300000
# ...           ...            ...
# 32543          52         720000
# 32544          58         780000
# 32551          58         780000
# 32562          61         160000
# 32579          56         150000
#
# [1454 rows x 2 columns]

# %%
df.drop(index=outliers.index, inplace=True)

# %%
sns.boxplot(df['person_income'])
plt.xlabel('Person Income')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Credit History length Outliers

# %%
sns.boxplot(df['credit_history_length'])
plt.xlabel('Credit History Length')
plt.ylabel('Count')
plt.title('Distribution of Credit History Length')
plt.show()

# %%
# Calculate Q1, Q3, and IQR
Q1 = df['credit_history_length'].quantile(0.25)
Q3 = df['credit_history_length'].quantile(0.75)
IQR = Q3 - Q1

# Calculate lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['credit_history_length'] < lower_bound) | (df['credit_history_length'] > upper_bound)]

print("Outliers:",outliers['credit_history_length'])
# Out:
# Outliers: 29125    17
# 29130    17
# 29134    17
# 29141    17
# 29179    16
#          ..
# 32575    20
# 32576    30
# 32577    19
# 32578    28
# 32580    30
# Name: credit_history_length, Length: 915, dtype: int64

# %%
sns.scatterplot(x=df['person_age'],y=df['credit_history_length'])
plt.show()

# %% [markdown]
# ### Outliers have meaning in data So I won't Remove it

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univariant Analysis

# %%
df.sample(10)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 649            23          58800                  RENT                7.0
# 1015           23          63000                  RENT                2.0
# 9              21          10000                   OWN                6.0
# 7239           22          52000              MORTGAGE                6.0
# 25341          30          25716                  RENT                1.0
# 3406           22          36000              MORTGAGE                2.0
# 24346          27          48000                  RENT                0.0
# 13422          21          27000                  RENT                3.0
# 28931          27          62900                  RENT                7.0
# 8258           24          40000                  RENT                1.0
#
#              loan_intent loan_grade  loan_amnt  loan_interest_rate  \
# 649    DEBTCONSOLIDATION          A      20000                7.66
# 1015           EDUCATION          C      18000               13.57
# 9                VENTURE          D       1600               14.74
# 7239           EDUCATION          C       9750               13.06
# 25341           PERSONAL          C       3000               13.72
# 3406   DEBTCONSOLIDATION          A      10000                8.32
# 24346            MEDICAL          B      10000               10.62
# 13422           PERSONAL          C       2600               13.22
# 28931            MEDICAL          D      24250               15.31
# 8258            PERSONAL          A       7500                5.79
#
#        loan_status  loan_percent_income historical_default  \
# 649              1                 0.34                  N
# 1015             0                 0.29                  Y
# 9                1                 0.16                  N
# 7239             0                 0.19                  N
# 25341            0                 0.12                  N
# 3406             0                 0.28                  N
# 24346            0                 0.21                  N
# 13422            0                 0.10                  Y
# 28931            1                 0.33                  N
# 8258             0                 0.19                  N
#
#        credit_history_length
# 649                        3
# 1015                       3
# 9                          3
# 7239                       3
# 25341                     10
# 3406                       3
# 24346                      6
# 13422                      2
# 28931                      6
# 8258                       4

# %%
for col in ['person_home_ownership', 'loan_intent', 'loan_grade', 'loan_status', 'historical_default']:
    sns.countplot(x=df[col])
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
for col in ['person_age', 'person_income', 'person_emp_length', 'loan_amnt', 'loan_interest_rate', 'credit_history_length']:
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
numeric_cols = df.select_dtypes(include=np.number)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,8)
sns.heatmap(numeric_cols.corr(), vmax =.8, square = True, annot = True )
plt.title('Confusion Matrix',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
df.to_csv('clean_credit_risk.csv',sep=',',index=False, header=True, encoding=None)

# %%
from autoviz import AutoViz_Class
# %matplotlib inline
AV = AutoViz_Class()
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
filename = "clean_credit_risk.csv"
viz = AV.AutoViz(filename=filename,verbose=2,sep=',',chart_format='svg')
# Out:
# Shape of your Data Set loaded: (28007, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing up to 30 columns (max) in each category:
#     Numeric Columns : ['person_emp_length', 'loan_interest_rate', 'loan_percent_income']
#     Integer-Categorical Columns: ['person_age', 'person_income', 'loan_amnt', 'credit_history_length']
#     String-Categorical Columns: ['person_home_ownership', 'loan_intent', 'loan_grade']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: ['historical_default']
#     Numeric-Boolean Columns: ['loan_status']
#     Discrete String Columns: []
#     NLP text Columns: []
#     Date Time Columns: []
#     ID Columns: []
#     Columns that will not be considered in modeling: []
#     12 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
#    Columns to delete:
# '   []'
#    Boolean variables %s
# "   ['historical_default', 'loan_status']"
#    Categorical variables %s
# ("   ['person_home_ownership', 'loan_intent', 'loan_grade', 'person_age', "
#  "'person_income', 'loan_amnt', 'credit_history_length', 'historical_default', "
#  "'loan_status']")
#    Continuous variables %s
# "   ['person_emp_length', 'loan_interest_rate', 'loan_percent_income']"
#    Discrete string variables %s
# '   []'
#    Date and time variables %s
# '   []'
#    ID variables %s
# '   []'
#    Target variable %s
# '   '
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
# There are 138 duplicate rows in your dataset
#     Alert: Dropping duplicate rows can sometimes cause your column data types to change to object!
#     All variables classified into correct types.
# <style type="text/css">
# #T_f1066_row0_col0, #T_f1066_row0_col2, #T_f1066_row0_col3, #T_f1066_row0_col4, #T_f1066_row0_col5, #T_f1066_row1_col0, #T_f1066_row1_col2, #T_f1066_row1_col3, #T_f1066_row1_col4, #T_f1066_row1_col5, #T_f1066_row2_col0, #T_f1066_row2_col2, #T_f1066_row2_col3, #T_f1066_row2_col4, #T_f1066_row2_col5, #T_f1066_row3_col0, #T_f1066_row3_col2, #T_f1066_row3_col3, #T_f1066_row3_col4, #T_f1066_row3_col5, #T_f1066_row4_col0, #T_f1066_row4_col2, #T_f1066_row4_col3, #T_f1066_row4_col4, #T_f1066_row4_col5, #T_f1066_row5_col0, #T_f1066_row5_col2, #T_f1066_row5_col3, #T_f1066_row5_col4, #T_f1066_row5_col5, #T_f1066_row6_col0, #T_f1066_row6_col2, #T_f1066_row6_col3, #T_f1066_row6_col4, #T_f1066_row6_col5, #T_f1066_row7_col0, #T_f1066_row7_col2, #T_f1066_row7_col3, #T_f1066_row7_col4, #T_f1066_row7_col5, #T_f1066_row8_col0, #T_f1066_row8_col2, #T_f1066_row8_col3, #T_f1066_row8_col4, #T_f1066_row8_col5, #T_f1066_row9_col0, #T_f1066_row9_col2, #T_f1066_row9_col3, #T_f1066_row9_col4, #T_f1066_row9_col5, #T_f1066_row10_col0, #T_f1066_row10_col2, #T_f1066_row10_col3, #T_f1066_row10_col4, #T_f1066_row10_col5, #T_f1066_row11_col0, #T_f1066_row11_col2, #T_f1066_row11_col3, #T_f1066_row11_col4, #T_f1066_row11_col5 {
#   font-family: Segoe UI;
# }
# #T_f1066_row0_col1, #T_f1066_row1_col1, #T_f1066_row2_col1, #T_f1066_row3_col1, #T_f1066_row4_col1, #T_f1066_row5_col1, #T_f1066_row6_col1, #T_f1066_row7_col1, #T_f1066_row8_col1, #T_f1066_row9_col1, #T_f1066_row10_col1, #T_f1066_row11_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_f1066">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1066_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_f1066_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_f1066_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_f1066_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_f1066_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_f1066_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1066_level0_row0" class="row_heading level0 row0" >person_age</th>
#       <td id="T_f1066_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_f1066_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_f1066_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_f1066_row0_col3" class="data row0 col3" >20.000000</td>
#       <td id="T_f1066_row0_col4" class="data row0 col4" >84.000000</td>
#       <td id="T_f1066_row0_col5" class="data row0 col5" >Column has 1207 outliers greater than upper bound (40.50) or lower than lower bound(12.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_f1066_level0_row1" class="row_heading level0 row1" >person_income</th>
#       <td id="T_f1066_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_f1066_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_f1066_row1_col2" class="data row1 col2" >13</td>
#       <td id="T_f1066_row1_col3" class="data row1 col3" >4000.000000</td>
#       <td id="T_f1066_row1_col4" class="data row1 col4" >139380.000000</td>
#       <td id="T_f1066_row1_col5" class="data row1 col5" >Column has 229 outliers greater than upper bound (130530.00) or lower than lower bound(-17550.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_f1066_level0_row2" class="row_heading level0 row2" >person_home_ownership</th>
#       <td id="T_f1066_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_f1066_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_f1066_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_f1066_row2_col3" class="data row2 col3" ></td>
#       <td id="T_f1066_row2_col4" class="data row2 col4" ></td>
#       <td id="T_f1066_row2_col5" class="data row2 col5" >1 rare categories: ['OTHER']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_f1066_level0_row3" class="row_heading level0 row3" >person_emp_length</th>
#       <td id="T_f1066_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_f1066_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_f1066_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_f1066_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_f1066_row3_col4" class="data row3 col4" >38.000000</td>
#       <td id="T_f1066_row3_col5" class="data row3 col5" >Column has 681 outliers greater than upper bound (14.50) or lower than lower bound(-5.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_f1066_level0_row4" class="row_heading level0 row4" >loan_intent</th>
#       <td id="T_f1066_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_f1066_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_f1066_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_f1066_row4_col3" class="data row4 col3" ></td>
#       <td id="T_f1066_row4_col4" class="data row4 col4" ></td>
#       <td id="T_f1066_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_f1066_level0_row5" class="row_heading level0 row5" >loan_grade</th>
#       <td id="T_f1066_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_f1066_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_f1066_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_f1066_row5_col3" class="data row5 col3" ></td>
#       <td id="T_f1066_row5_col4" class="data row5 col4" ></td>
#       <td id="T_f1066_row5_col5" class="data row5 col5" >2 rare categories: ['F', 'G']. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_f1066_level0_row6" class="row_heading level0 row6" >loan_amnt</th>
#       <td id="T_f1066_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_f1066_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_f1066_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_f1066_row6_col3" class="data row6 col3" >500.000000</td>
#       <td id="T_f1066_row6_col4" class="data row6 col4" >35000.000000</td>
#       <td id="T_f1066_row6_col5" class="data row6 col5" >Column has 1204 outliers greater than upper bound (22500.00) or lower than lower bound(-5500.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_f1066_level0_row7" class="row_heading level0 row7" >loan_interest_rate</th>
#       <td id="T_f1066_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_f1066_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_f1066_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_f1066_row7_col3" class="data row7 col3" >5.420000</td>
#       <td id="T_f1066_row7_col4" class="data row7 col4" >23.220000</td>
#       <td id="T_f1066_row7_col5" class="data row7 col5" >Column has 5 outliers greater than upper bound (21.83) or lower than lower bound(-0.46). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_f1066_level0_row8" class="row_heading level0 row8" >loan_status</th>
#       <td id="T_f1066_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_f1066_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_f1066_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_f1066_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_f1066_row8_col4" class="data row8 col4" >1.000000</td>
#       <td id="T_f1066_row8_col5" class="data row8 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_f1066_level0_row9" class="row_heading level0 row9" >loan_percent_income</th>
#       <td id="T_f1066_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_f1066_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_f1066_row9_col2" class="data row9 col2" >NA</td>
#       <td id="T_f1066_row9_col3" class="data row9 col3" >0.010000</td>
#       <td id=
# Number of All Scatter Plots = 6
# All Plots are saved in .\AutoViz_Plots\AutoViz
# Time to run AutoViz = 7 seconds
